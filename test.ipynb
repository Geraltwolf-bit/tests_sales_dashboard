# %%
import pandas as pd
df = pd.read_csv('df.csv')
df.drop(columns='Unnamed: 0', inplace=True)
df
# Out:
#       quantity       price            city                 date  year  \
# 0         1500  170.310000          Абакан           2024-04-07  2024
# 1          260  521.000000          Ижевск           2024-11-25  2024
# 2          180  521.000000          Ижевск           2024-11-21  2024
# 3          780  205.076923          Ижевск           2024-11-18  2024
# 4          370  212.213600          Ижевск           2024-11-18  2024
# ...        ...         ...             ...                  ...   ...
# 2203      1500  155.828700            Чита  2024-12-17 00:00:00  2024
# 2204       750  172.470600            Чита  2024-12-12 00:00:00  2024
# 2205      1800  181.048743          Абакан  2024-12-10 00:00:00  2024
# 2206      8010  154.315800  Южно-Сахалинск  2024-12-16 00:00:00  2024
# 2207      1530  186.566400           Янаул  2024-12-07 00:00:00  2024
#
#              total month_of_year                 region region_type  \
# ...

# %%
import plotly.express as px

total = df.groupby('year')['total'].sum().reset_index(drop = True)
total
# Out:
# 0    3.023332e+08
# 1    2.827071e+08
# 2    2.678484e+08
# Name: total, dtype: float64
